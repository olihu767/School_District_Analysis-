# %%
import pandas as pd

# %%
file_to_load_1 = "Resources/students_complete.csv"

# %%
file_to_load_2 = "Resources/schools_complete.csv"

# %%
students_data_df= pd.read_csv(file_to_load_1)

# %%
schools_data_df=pd.read_csv(file_to_load_2)

# %%
students_data_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# %%
for word in prefixes_suffixes:
    students_data_df["student_name"] = students_data_df['student_name'].str.replace(word,"")

# %%
students_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# ...

# %%
import numpy as np

# %%
students_data_df.loc[(students_data_df['grade']=="9th")&(students_data_df['school_name']=='Thomas High School'),'reading_score':"math_score"]=np.nan

# %%
students_data_df.tail(10)
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39160       39160     Katie Weaver      F  11th  Thomas High School
# 39161       39161      April Reyes      F  10th  Thomas High School
# 39162       39162      Derek Weeks      M  12th  Thomas High School
# 39163       39163       John Reese      M  11th  Thomas High School
# 39164       39164   Joseph Anthony      M   9th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 39160           89.0        86.0
# 39161           70.0        84.0
# 39162           94.0        77.0
# 39163           90.0        75.0
# 39164            NaN         NaN
# ...

# %%
#Merge Student_data_df with school data
Merge_data_df = pd.merge(students_data_df, schools_data_df, on =['school_name'])

# %%
Merge_data_df.tail(10)
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39160       39160     Katie Weaver      F  11th  Thomas High School
# 39161       39161      April Reyes      F  10th  Thomas High School
# 39162       39162      Derek Weeks      M  12th  Thomas High School
# 39163       39163       John Reese      M  11th  Thomas High School
# 39164       39164   Joseph Anthony      M   9th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID     type  size   budget
# 39160           89.0        86.0         14  Charter  1635  1043130
# 39161           70.0        84.0         14  Charter  1635  1043130
# ...

# %%
students_count_1 = Merge_data_df.student_name.count()

# %%
school_count_1 =  len(Merge_data_df.school_name.unique())

# %%
total_budget_1 = Merge_data_df['budget'].sum()

# %%
avg_math_1 = Merge_data_df['math_score'].mean()

# %%
ave_reading_1 = Merge_data_df['reading_score'].mean()

# %%
passing_math_1_df = Merge_data_df[Merge_data_df["math_score"]>=70]
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39163       39163       John Reese      M  11th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0               66.0        79.0          0  District  2917  1910635
# ...

# %%
passing_reading_1_df = Merge_data_df[Merge_data_df["reading_score"]>=70]

# %%
passing_math_1_count=passing_math_1_df['student_name'].count()

# %%
passing_reading_1=passing_reading_1_df['student_name'].count()

# %%
passing_math_percentage_1 = passing_math_1_count / float(students_count_1)*100
passing_math_percentage_1
# Out:
# 73.88052080673985

# %%
passing_reading_percentage_1 = passing_reading_1 / float(students_count_1)*100

# %%
passing_math_reading_1 = Merge_data_df[
    (Merge_data_df['reading_score']>=70)&(Merge_data_df['math_score']>=70)]

# %%
overall_passing_math_reading_count_1 = passing_math_reading_1['student_name'].count()

# %%
overall_passing_percentage_1 = overall_passing_math_reading_count_1 / students_count_1*100

# %%
overall_passing_percentage_1
# Out:
# 64.09241766658157

# %%
#Adding a list of value with keys to create a new DataFrame
district_summary_df = pd.DataFrame(
[{'Total Schools': school_count_1,
 "Total Students": students_count_1,
 "Total Budget":total_budget_1,
 "Average Math Score":avg_math_1,
 "Average Reading Score":ave_reading_1,
 'Percentage Passing Math': passing_math_percentage_1,
 "% Passing Reading": passing_reading_percentage_1,
  '% Overall Passing': overall_passing_percentage_1,
 }])

# %%
district_summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170   82932329558           78.930533
#
#    Average Reading Score  Percentage Passing Math  % Passing Reading  \
# 0              81.855796                73.880521          84.651519
#
#    % Overall Passing
# 0          64.092418

# %%
per_school_types = Merge_data_df.set_index(['school_name'])['type']

# %%
per_school_size = Merge_data_df.set_index(['school_name'])['size']

# %%
per_school_budget = Merge_data_df.set_index(['school_name'])['budget']

# %%
per_school_captia = Merge_data
